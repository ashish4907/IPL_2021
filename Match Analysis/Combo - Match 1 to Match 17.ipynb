# %%
import pandas as pd
import os
pd.options.mode.chained_assignment= None

# %%
files= [file for file in os.listdir('./CSV Files')]

all_matches_data=pd.DataFrame()

for file in files:
    df=pd.read_csv('./CSV Files/'+file)
    all_matches_data=pd.concat([all_matches_data,df])

# %%
# all_matches_data.to_csv('Combo_Match1_to_Match17.csv',index=False)

# %%
 df= pd.read_csv('Combo CSV Files\Combo_Match1_to_Match17.csv',index_col='Players')

# %%
df.Sixes.sum()
# Out:
# 217

# %%
df.Fours.sum()
# Out:
# 485

# %%
df.groupby('Team').Fours.sum().nlargest(8)
# Out:
# Team
# Delhi Capitals                79
# Royal Challengers Banglore    65
# Punjab Kings                  64
# Kolkata Knight Riders         62
# Rajasthan Royals              62
# Chennai Super Kings           61
# Mumbai Indians                59
# Sunrisers Hyderabad           33
# Name: Fours, dtype: int64

# %%
df.groupby('Team').Sixes.sum().nlargest(8)
# Out:
# Team
# Chennai Super Kings           34
# Kolkata Knight Riders         34
# Punjab Kings                  33
# Rajasthan Royals              31
# Sunrisers Hyderabad           26
# Royal Challengers Banglore    24
# Mumbai Indians                23
# Delhi Capitals                12
# Name: Sixes, dtype: int64

# %% [markdown]
# # 1. BATSMAN

# %%
Batsman=df[['Team','Match Played','Batsman Runs','Balls','Fours','Sixes','Strike Rate','50s','100s','Vs','Times Out']]

# %%
Batsman.replace(to_replace=['Yes','No'],value=[0,1],inplace=True)

# %%
Batsman['Times Out'] = Batsman['Times Out'].astype(float)

# %%
BR=Batsman.groupby(by=['Players','Team'])[['Match Played','Batsman Runs','Balls','Fours','Sixes','50s','100s','Vs','Times Out']].sum().nlargest(1000,'Batsman Runs')

# %%
BR['Strike Rate'] = BR['Batsman Runs']/BR['Balls']*100

# %%
batsman= BR.round(2)

# %%
batsman.loc[batsman['Balls'] >=1 , 'Innings'] = batsman['Match Played']

# %%
batsman.loc[(batsman['Times Out'] == 0) & (batsman['Match Played'] >=1) ,'Average'] = batsman['Batsman Runs']/batsman['Match Played']
batsman.loc[(batsman['Times Out'] == 1) & (batsman['Match Played'] == 1),'Average'] = batsman['Batsman Runs']
batsman.loc[(batsman['Times Out'] == 1) & (batsman['Match Played'] >= 2),'Average'] = batsman['Batsman Runs']/(batsman['Match Played']-batsman['Times Out'])
batsman.loc[(batsman['Times Out'] == 2) & (batsman['Match Played'] == 2),'Average'] = batsman['Batsman Runs']
batsman.loc[(batsman['Times Out'] == 2) & (batsman['Match Played'] >= 3),'Average'] = batsman['Batsman Runs']/(batsman['Match Played']-batsman['Times Out'])
batsman.loc[(batsman['Times Out'] == 3) & (batsman['Match Played'] == 3),'Average'] = batsman['Batsman Runs']
batsman.loc[(batsman['Times Out'] == 3) & (batsman['Match Played'] >=4),'Average'] = batsman['Batsman Runs']/(batsman['Match Played']-batsman['Times Out'])
batsman.loc[(batsman['Times Out'] == 4) & (batsman['Match Played'] ==4),'Average'] = batsman['Batsman Runs']
batsman.loc[(batsman['Times Out'] == 4) & (batsman['Match Played'] >=5),'Average'] = batsman['Batsman Runs']/(batsman['Match Played']-batsman['Times Out'])
batsman.loc[(batsman['Times Out'] == 5) & (batsman['Match Played'] ==5),'Average'] = batsman['Batsman Runs']

# %% [markdown]
# # 1. a) Most Runs

# %%
batsman[['Match Played','Batsman Runs','Average']].nlargest(15,'Batsman Runs').round(2)
# Out:
#                                              Match Played  Batsman Runs  \
# Players          Team
# Shikhar Dhawan   Delhi Capitals                         4           231
# KL Rahul         Punjab Kings                           5           221
# Rohit Sharma     Mumbai Indians                         5           201
# Glenn Maxwell    Royal Challengers Banglore             4           176
# Jonny Bairstow   Sunrisers Hyderabad                    4           173
# du Plessis       Chennai Super Kings                    4           164
# Nitish Rana      Kolkata Knight Riders                  4           164
# Suryakumar Yadav Mumbai Indians                         5           154
# Sanju Samson     Rajasthan Royals                       4           145
# Virat Kohli      Royal Challengers Banglore             4           143
# Devdutt Padikkal Royal Challengers Banglore             3           137
# Moeen Ali        Chennai Super Kings                    4           133
# David Warner     Sunrisers Hyderabad                    4           130
# Mayank Agarwal   Punjab Kings                           5           130
# AB de Villiers   Royal Challengers Banglore             4           125
#
#                                              Average
# Players          Team
# Shikhar Dhawan   Delhi Capitals                57.75
# KL Rahul         Punjab Kings                  55.25
# Rohit Sharma     Mumbai Indians                40.20
# Glenn Maxwell    Royal Challengers Banglore    58.67
# Jonny Bairstow   Sunrisers Hyderabad           57.67
# du Plessis       Chennai Super Kings           82.00
# Nitish Rana      Kolkata Knight Riders         41.00
# Suryakumar Yadav Mumbai Indians                30.80
# Sanju Samson     Rajasthan Royals              36.25
# Virat Kohli      Royal Challengers Banglore    47.67
# Devdutt Padikkal Royal Challengers Banglore    68.50
# Moeen Ali        Chennai Super Kings           33.25
# David Warner     Sunrisers Hyderabad           32.50
# Mayank Agarwal   Punjab Kings                  26.00
# AB de Villiers   Royal Challengers Banglore    62.50

# %% [markdown]
# # 2. b) Highest Scores

# %%
Batsman[['Batsman Runs','Balls','Strike Rate','Vs']].nlargest(15,'Batsman Runs')
# Out:
#                   Batsman Runs  Balls  Strike Rate    Vs
# Players
# Sanju Samson               119     63       188.89  PBKS
# Devdutt Padikkal           101     52       194.23    RR
# du Plessis                  95     60       158.33   KKR
# Shikhar Dhawan              92     49       187.76  PBKS
# KL Rahul                    91     50       182.00    RR
# Shikhar Dhawan              85     54       157.41   CSK
# Nitish Rana                 80     56       142.86   SRH
# Glenn Maxwell               78     49       159.18   KKR
# AB de Villiers              76     34       223.53   KKR
# Virat Kohli                 72     47       153.19    RR
# Prithvi Shaw                72     38       189.47   CSK
# Mayank Agarwal              69     36       191.67    DC
# Pat Cummins                 66     34       194.12   CSK
# Rituraj Gaikwad             64     42       152.38   KKR
# Deepak Hooda                64     28       228.57    RR

# %% [markdown]
# # 1. c) Best Batting Average

# %%
Avg= batsman[batsman['Match Played'] >=2]
Avg[['Match Played','Batsman Runs','Average']].nlargest(15,'Average').round(2)
# Out:
#                                              Match Played  Batsman Runs  \
# Players          Team
# du Plessis       Chennai Super Kings                    4           164
# Devdutt Padikkal Royal Challengers Banglore             3           137
# AB de Villiers   Royal Challengers Banglore             4           125
# Glenn Maxwell    Royal Challengers Banglore             4           176
# Shikhar Dhawan   Delhi Capitals                         4           231
# Jonny Bairstow   Sunrisers Hyderabad                    4           173
# KL Rahul         Punjab Kings                           5           221
# Lalit Yadav      Delhi Capitals                         3            54
# Manish Pandey    Sunrisers Hyderabad                    3           101
# Virat Kohli      Royal Challengers Banglore             4           143
# Shahrukh Khan    Punjab Kings                           5            90
# Nitish Rana      Kolkata Knight Riders                  4           164
# Rohit Sharma     Mumbai Indians                         5           201
# Deepak Hooda     Punjab Kings                           5           109
# Sanju Samson     Rajasthan Royals                       4           145
#
#                                              Average
# Players          Team
# du Plessis       Chennai Super Kings           82.00
# Devdutt Padikkal Royal Challengers Banglore    68.50
# AB de Villiers   Royal Challengers Banglore    62.50
# Glenn Maxwell    Royal Challengers Banglore    58.67
# Shikhar Dhawan   Delhi Capitals                57.75
# Jonny Bairstow   Sunrisers Hyderabad           57.67
# KL Rahul         Punjab Kings                  55.25
# Lalit Yadav      Delhi Capitals                54.00
# Manish Pandey    Sunrisers Hyderabad           50.50
# Virat Kohli      Royal Challengers Banglore    47.67
# Shahrukh Khan    Punjab Kings                  45.00
# Nitish Rana      Kolkata Knight Riders         41.00
# Rohit Sharma     Mumbai Indians                40.20
# Deepak Hooda     Punjab Kings                  36.33
# Sanju Samson     Rajasthan Royals              36.25

# %% [markdown]
# # 1. d) Best Batting Strike Rate

# %%
SR= batsman[batsman['Batsman Runs'] >=50]
SR[['Match Played','Batsman Runs','Strike Rate']].nlargest(15,'Strike Rate')
# Out:
#                                              Match Played  Batsman Runs  \
# Players          Team
# Sam Curran       Chennai Super Kings                    4            52
# Pat Cummins      Kolkata Knight Riders                  4            72
# AB de Villiers   Royal Challengers Banglore             4           125
# Prithvi Shaw     Delhi Capitals                         4           113
# Sanju Samson     Rajasthan Royals                       4           145
# Deepak Hooda     Punjab Kings                           5           109
# Andre Russell    Kolkata Knight Riders                  4            99
# Moeen Ali        Chennai Super Kings                    4           133
# Glenn Maxwell    Royal Challengers Banglore             4           176
# Shikhar Dhawan   Delhi Capitals                         4           231
# Devdutt Padikkal Royal Challengers Banglore             3           137
# Ambati Rayudu    Chennai Super Kings                    4            50
# Dinesh Karthik   Kolkata Knight Riders                  4            72
# Shubman Gill     Kolkata Knight Riders                  4            69
# Shahrukh Khan    Punjab Kings                           5            90
#
#                                              Strike Rate
# Players          Team
# Sam Curran       Chennai Super Kings              208.00
# Pat Cummins      Kolkata Knight Riders            194.59
# AB de Villiers   Royal Challengers Banglore       189.39
# Prithvi Shaw     Delhi Capitals                   173.85
# Sanju Samson     Rajasthan Royals                 162.92
# Deepak Hooda     Punjab Kings                     162.69
# Andre Russell    Kolkata Knight Riders            159.68
# Moeen Ali        Chennai Super Kings              152.87
# Glenn Maxwell    Royal Challengers Banglore       149.15
# Shikhar Dhawan   Delhi Capitals                   148.08
# Devdutt Padikkal Royal Challengers Banglore       147.31
# Ambati Rayudu    Chennai Super Kings              147.06
# Dinesh Karthik   Kolkata Knight Riders            146.94
# Shubman Gill     Kolkata Knight Riders            146.81
# Shahrukh Khan    Punjab Kings                     145.16

# %% [markdown]
# # 1. e) Most Hundreds

# %%
batsman[['Match Played','Batsman Runs','100s']].nlargest(2,'100s')
# Out:
#                                              Match Played  Batsman Runs  100s
# Players          Team
# Sanju Samson     Rajasthan Royals                       4           145     1
# Devdutt Padikkal Royal Challengers Banglore             3           137     1

# %% [markdown]
# # 1. f) Most Fifties

# %%
batsman[['Match Played','Batsman Runs','50s']].nlargest(15,'50s')
# Out:
#                                              Match Played  Batsman Runs  50s
# Players          Team
# KL Rahul         Punjab Kings                           5           221    3
# Shikhar Dhawan   Delhi Capitals                         4           231    2
# Glenn Maxwell    Royal Challengers Banglore             4           176    2
# Jonny Bairstow   Sunrisers Hyderabad                    4           173    2
# Nitish Rana      Kolkata Knight Riders                  4           164    2
# Rohit Sharma     Mumbai Indians                         5           201    1
# du Plessis       Chennai Super Kings                    4           164    1
# Suryakumar Yadav Mumbai Indians                         5           154    1
# Virat Kohli      Royal Challengers Banglore             4           143    1
# David Warner     Sunrisers Hyderabad                    4           130    1
# Mayank Agarwal   Punjab Kings                           5           130    1
# AB de Villiers   Royal Challengers Banglore             4           125    1
# Prithvi Shaw     Delhi Capitals                         4           113    1
# Deepak Hooda     Punjab Kings                           5           109    1
# Manish Pandey    Sunrisers Hyderabad                    3           101    1

# %% [markdown]
# # 1. g) Most Fours

# %%
batsman[['Match Played','Batsman Runs','Fours']].nlargest(15,'Fours')
# Out:
#                                              Match Played  Batsman Runs  Fours
# Players          Team
# Shikhar Dhawan   Delhi Capitals                         4           231     29
# Nitish Rana      Kolkata Knight Riders                  4           164     19
# Suryakumar Yadav Mumbai Indians                         5           154     19
# KL Rahul         Punjab Kings                           5           221     18
# Glenn Maxwell    Royal Challengers Banglore             4           176     17
# du Plessis       Chennai Super Kings                    4           164     16
# Sanju Samson     Rajasthan Royals                       4           145     15
# Virat Kohli      Royal Challengers Banglore             4           143     15
# Devdutt Padikkal Royal Challengers Banglore             3           137     15
# Mayank Agarwal   Punjab Kings                           5           130     15
# Rohit Sharma     Mumbai Indians                         5           201     14
# Moeen Ali        Chennai Super Kings                    4           133     14
# AB de Villiers   Royal Challengers Banglore             4           125     13
# Chris Gayle      Punjab Kings                           5           119     13
# Prithvi Shaw     Delhi Capitals                         4           113     13

# %% [markdown]
# # 1. h) Most Sixes

# %%
batsman[['Match Played','Batsman Runs','Sixes']].nlargest(15,'Sixes')
# Out:
#                                              Match Played  Batsman Runs  Sixes
# Players          Team
# KL Rahul         Punjab Kings                           5           221     10
# Jonny Bairstow   Sunrisers Hyderabad                    4           173     10
# Rohit Sharma     Mumbai Indians                         5           201      9
# Glenn Maxwell    Royal Challengers Banglore             4           176      8
# Sanju Samson     Rajasthan Royals                       4           145      8
# Deepak Hooda     Punjab Kings                           5           109      8
# Andre Russell    Kolkata Knight Riders                  4            99      8
# du Plessis       Chennai Super Kings                    4           164      7
# Nitish Rana      Kolkata Knight Riders                  4           164      7
# Moeen Ali        Chennai Super Kings                    4           133      7
# Pat Cummins      Kolkata Knight Riders                  4            72      7
# Devdutt Padikkal Royal Challengers Banglore             3           137      6
# Shikhar Dhawan   Delhi Capitals                         4           231      5
# Suryakumar Yadav Mumbai Indians                         5           154      5
# Mayank Agarwal   Punjab Kings                           5           130      5

# %% [markdown]
# # 2. BOWLER

# %%
bowler_played= df[['Team','Match Played','Over','Bowler Balls','Maiden','Bowler Runs','Wickets','Economy Rate','Vs']]

# %%
Bowler= bowler_played[bowler_played['Bowler Balls'] >=1]

# %%
W= Bowler.groupby(by=['Players','Team'])[['Match Played','Over','Bowler Balls','Maiden','Bowler Runs','Wickets']].sum().nlargest(100,'Wickets')

# %%
W['Economy'] = W['Bowler Runs']/W['Over']

# %%
W['Average'] = W['Bowler Runs']/W['Wickets']

# %%
W['Strike Rate'] = W['Bowler Balls']/W['Wickets']

# %%
bowler = W.round(2)

# %%
bowler['Wickets'] =bowler['Wickets'].astype(int)

# %%
bowler.sort_values(by='Wickets',ascending=False).shape
# Out:
# (74, 9)

# %% [markdown]
# # 2. a) Most Wickets

# %%
bowler[['Match Played','Over','Wickets','Average']].nlargest(15,'Wickets')
# Out:
#                                             Match Played  Over  Wickets  \
# Players         Team
# Harshal Patel   Royal Challengers Banglore             4  16.0       12
# Rahul Chahar    Mumbai Indians                         5  20.0        9
# Avesh Khan      Delhi Capitals                         4  14.0        8
# Deepak Chahar   Chennai Super Kings                    4  15.0        8
# Andre Russell   Kolkata Knight Riders                  4   9.0        7
# Mohammed Shami  Punjab Kings                           5  18.0        6
# Arshdeep Singh  Punjab Kings                           5  15.4        6
# Trent Boult     Mumbai Indians                         5  17.8        6
# Chetan Sakariya Rajasthan Royals                       4  16.0        6
# Kyle Jamieson   Royal Challengers Banglore             4  14.0        6
# Mohammed Siraj  Royal Challengers Banglore             4  15.0        5
# Rashid Khan     Sunrisers Hyderabad                    4  16.0        5
# Chris Woakes    Delhi Capitals                         3  11.0        5
# Chris Morris    Rajasthan Royals                       4  14.0        5
# Jasprit Bumrah  Mumbai Indians                         5  19.0        4
#
#                                             Average
# Players         Team
# Harshal Patel   Royal Challengers Banglore     9.67
# Rahul Chahar    Mumbai Indians                15.22
# Avesh Khan      Delhi Capitals                12.88
# Deepak Chahar   Chennai Super Kings           13.75
# Andre Russell   Kolkata Knight Riders         16.00
# Mohammed Shami  Punjab Kings                  24.00
# Arshdeep Singh  Punjab Kings                  20.50
# Trent Boult     Mumbai Indians                24.00
# Chetan Sakariya Rajasthan Royals              22.50
# Kyle Jamieson   Royal Challengers Banglore    21.00
# Mohammed Siraj  Royal Challengers Banglore    18.20
# Rashid Khan     Sunrisers Hyderabad           16.20
# Chris Woakes    Delhi Capitals                16.40
# Chris Morris    Rajasthan Royals              27.80
# Jasprit Bumrah  Mumbai Indians                30.25

# %% [markdown]
# # 2. b) Best Bowling Average

# %%
BA= bowler[bowler['Wickets'] >5]
BA[['Match Played','Over','Wickets','Average']].nsmallest(15,'Average')
# Out:
#                                             Match Played  Over  Wickets  \
# Players         Team
# Harshal Patel   Royal Challengers Banglore             4  16.0       12
# Avesh Khan      Delhi Capitals                         4  14.0        8
# Deepak Chahar   Chennai Super Kings                    4  15.0        8
# Rahul Chahar    Mumbai Indians                         5  20.0        9
# Andre Russell   Kolkata Knight Riders                  4   9.0        7
# Arshdeep Singh  Punjab Kings                           5  15.4        6
# Kyle Jamieson   Royal Challengers Banglore             4  14.0        6
# Chetan Sakariya Rajasthan Royals                       4  16.0        6
# Mohammed Shami  Punjab Kings                           5  18.0        6
# Trent Boult     Mumbai Indians                         5  17.8        6
#
#                                             Average
# Players         Team
# Harshal Patel   Royal Challengers Banglore     9.67
# Avesh Khan      Delhi Capitals                12.88
# Deepak Chahar   Chennai Super Kings           13.75
# Rahul Chahar    Mumbai Indians                15.22
# Andre Russell   Kolkata Knight Riders         16.00
# Arshdeep Singh  Punjab Kings                  20.50
# Kyle Jamieson   Royal Challengers Banglore    21.00
# Chetan Sakariya Rajasthan Royals              22.50
# Mohammed Shami  Punjab Kings                  24.00
# Trent Boult     Mumbai Indians                24.00

# %% [markdown]
# # 2. c) Best Economy

# %%
BE= bowler[bowler['Wickets'] >=1]
BE[['Match Played','Over','Wickets','Economy']].nsmallest(15,'Economy')
# Out:
#                                             Match Played  Over  Wickets  \
# Players         Team
# Rashid Khan     Sunrisers Hyderabad                    4  16.0        5
# Ravi Bishoni    Punjab Kings                           1   4.0        2
# Lalit Yadav     Delhi Capitals                         2   5.0        1
# Khaleel Ahmed   Sunrisers Hyderabad                    2   8.0        4
# Jayant Yadav    Mumbai Indians                         2   8.0        1
# Abhishek Sharma Sunrisers Hyderabad                    2   5.0        2
# Mohammed Siraj  Royal Challengers Banglore             4  15.0        5
# Deepak Hooda    Punjab Kings                           3   9.0        1
# Moeen Ali       Chennai Super Kings                    3   9.0        4
# Jasprit Bumrah  Mumbai Indians                         5  19.0        4
# Rahul Chahar    Mumbai Indians                         5  20.0        9
# Ravindra Jadeja Chennai Super Kings                    4  14.0        2
# Jaydev Unadkat  Rajasthan Royals                       2   8.0        3
# Lungi Ngidi     Chennai Super Kings                    1   4.0        3
# Shahbaz Ahmed   Royal Challengers Banglore             2   3.0        3
#
#                                             Economy
# Players         Team
# Rashid Khan     Sunrisers Hyderabad            5.06
# Ravi Bishoni    Punjab Kings                   5.25
# Lalit Yadav     Delhi Capitals                 5.60
# Khaleel Ahmed   Sunrisers Hyderabad            5.62
# Jayant Yadav    Mumbai Indians                 5.62
# Abhishek Sharma Sunrisers Hyderabad            5.80
# Mohammed Siraj  Royal Challengers Banglore     6.07
# Deepak Hooda    Punjab Kings                   6.11
# Moeen Ali       Chennai Super Kings            6.33
# Jasprit Bumrah  Mumbai Indians                 6.37
# Rahul Chahar    Mumbai Indians                 6.85
# Ravindra Jadeja Chennai Super Kings            6.86
# Jaydev Unadkat  Rajasthan Royals               6.88
# Lungi Ngidi     Chennai Super Kings            7.00
# Shahbaz Ahmed   Royal Challengers Banglore     7.00

# %% [markdown]
# # 2. d) Best Bowling Strike Rate

# %%
SR= bowler[bowler['Wickets'] >5]
SR[['Match Played','Over','Wickets','Strike Rate']].nsmallest(15,'Strike Rate')
# Out:
#                                             Match Played  Over  Wickets  \
# Players         Team
# Andre Russell   Kolkata Knight Riders                  4   9.0        7
# Harshal Patel   Royal Challengers Banglore             4  16.0       12
# Avesh Khan      Delhi Capitals                         4  14.0        8
# Deepak Chahar   Chennai Super Kings                    4  15.0        8
# Rahul Chahar    Mumbai Indians                         5  20.0        9
# Kyle Jamieson   Royal Challengers Banglore             4  14.0        6
# Arshdeep Singh  Punjab Kings                           5  15.4        6
# Chetan Sakariya Rajasthan Royals                       4  16.0        6
# Mohammed Shami  Punjab Kings                           5  18.0        6
# Trent Boult     Mumbai Indians                         5  17.8        6
#
#                                             Strike Rate
# Players         Team
# Andre Russell   Kolkata Knight Riders              7.71
# Harshal Patel   Royal Challengers Banglore         8.00
# Avesh Khan      Delhi Capitals                    10.50
# Deepak Chahar   Chennai Super Kings               11.25
# Rahul Chahar    Mumbai Indians                    13.33
# Kyle Jamieson   Royal Challengers Banglore        14.00
# Arshdeep Singh  Punjab Kings                      15.67
# Chetan Sakariya Rajasthan Royals                  16.00
# Mohammed Shami  Punjab Kings                      18.00
# Trent Boult     Mumbai Indians                    18.33

# %% [markdown]
# # 3. FIELDER

# %%
fielder_played = df[['Team','Match Played','Catches','Run Out']]

# %% [markdown]
# # 3 a) Catches

# %%
 fielder_played.groupby(by=['Players','Team'])[['Match Played','Catches']].sum().nlargest(10,'Catches')
# Out:
#                                              Match Played  Catches
# Players          Team
# Ravindra Jadeja  Chennai Super Kings                    4        7
# Shikhar Dhawan   Delhi Capitals                         4        7
# Deepak Hooda     Punjab Kings                           5        5
# AB de Villiers   Royal Challengers Banglore             4        4
# Daniel Christian Royal Challengers Banglore             2        4
# KL Rahul         Punjab Kings                           5        4
# Rishabh Pant     Delhi Capitals                         4        4
# Riyan Parag      Rajasthan Royals                       4        4
# Suryakumar Yadav Mumbai Indians                         5        4
# Dhoni            Chennai Super Kings                    4        3

# %% [markdown]
# # 3. b) Run Outs

# %%
fielder_played.groupby(by=['Players','Team'])[['Match Played','Run Out']].sum().nlargest(10,'Run Out')
# Out:
#                                            Match Played  Run Out
# Players        Team
# Hardik Pandya  Mumbai Indians                         5        2
# Krunal Pandya  Mumbai Indians                         5        2
# Virat Kohli    Royal Challengers Banglore             4        2
# Chris Woakes   Delhi Capitals                         3        1
# David Miller   Rajasthan Royals                       3        1
# David Warner   Sunrisers Hyderabad                    4        1
# Dinesh Karthik Kolkata Knight Riders                  4        1
# Jasprit Bumrah Mumbai Indians                         5        1
# Jonny Bairstow Sunrisers Hyderabad                    4        1
# Mohammed Siraj Royal Challengers Banglore             4        1

# %% [markdown]
# # 4. ALL - ROUNDERS

# %%
All_Rounder = df.groupby(by=['Players','Team'])[['Match Played','Batsman Runs','Balls','Fours','Sixes','Over','Bowler Balls','Bowler Runs','Maiden','Wickets','Catches','Run Out','50s','100s']].sum()

# %%
all_rounder= All_Rounder[(All_Rounder['Balls'] >1) & (All_Rounder['Wickets'] >=1)]

# %%
all_rounder.shape
# Out:
# (43, 14)

# %%
all_rounder['Economy Rate'] = all_rounder['Bowler Runs']/all_rounder['Over']

# %%
all_rounder['Strike Rate'] = all_rounder['Batsman Runs']/all_rounder['Balls']*100

# %%
all_rounders= all_rounder.round(2)

# %% [markdown]
# # 4. a) All-Rounder with highest Runs

# %%
all_rounders[['Match Played','Batsman Runs','Wickets']].nlargest(10,'Batsman Runs')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-412c90c24de7> in <module>
# ----> 1 all_rounders[['Match Played','Batsman Runs','Wickets']].nlargest(10,'Batsman Runs')
#
# NameError: name 'all_rounders' is not defined

# %% [markdown]
# # 4. b) All-Rounder with highest wickets

# %%
all_rounders[['Match Played','Batsman Runs','Wickets']].nlargest(10,'Wickets')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-8483a3a6e239> in <module>
# ----> 1 all_rounders[['Match Played','Batsman Runs','Wickets']].nlargest(10,'Wickets')
#
# NameError: name 'all_rounders' is not defined
