# %%
import pandas as pd
import os
pd.options.mode.chained_assignment= None

# %%
files= [file for file in os.listdir('./CSV Files')]

all_matches_data=pd.DataFrame()

for file in files:
    df=pd.read_csv('./CSV Files/'+file)
    all_matches_data=pd.concat([all_matches_data,df])

# %%
# all_matches_data.to_csv('Combo_Match1_to_Match12.csv',index=False)

# %%
 df= pd.read_csv('Combo CSV Files\Combo_Match1_to_Match12.csv',index_col='Players')

# %%
df.Sixes.sum()
# Out:
# 154

# %%
df.Fours.sum()
# Out:
# 358

# %%
df.groupby('Team').Fours.sum().nlargest(8)
# Out:
# Team
# Delhi Capitals                65
# Royal Challengers Banglore    48
# Kolkata Knight Riders         46
# Punjab Kings                  45
# Rajasthan Royals              44
# Chennai Super Kings           42
# Mumbai Indians                41
# Sunrisers Hyderabad           27
# Name: Fours, dtype: int64

# %%
df.groupby('Team').Sixes.sum().nlargest(8)
# Out:
# Team
# Punjab Kings                  25
# Rajasthan Royals              24
# Chennai Super Kings           22
# Sunrisers Hyderabad           22
# Kolkata Knight Riders         20
# Mumbai Indians                15
# Royal Challengers Banglore    15
# Delhi Capitals                11
# Name: Sixes, dtype: int64

# %% [markdown]
# # BATSMAN

# %%
df.head(1)
# Out:
#                         Team  Match Played  Batsman Runs  Balls  Fours  Sixes  \
# Players
# Rohit Sharma  Mumbai Indians             1            19     15      1      1
#
#               Strike Rate  Over  Bowler Balls  Maiden  Bowler Runs  Wickets  \
# Players
# Rohit Sharma       126.67   0.0             0       0            0        0
#
#               Economy Rate  Catches  Run Out  50s  100s   Vs Times Out
# Players
# Rohit Sharma           0.0        0        0    0     0  RCB       Yes

# %%
batsman_played= df[['Team','Match Played','Batsman Runs','Balls','Fours','Sixes','Strike Rate','50s','100s','Vs','Times Out']]

# %%
Batsman= batsman_played[batsman_played['Balls'] >=1]

# %%
Batsman.replace(to_replace=['Yes','No'],value=[0,1],inplace=True)

# %%
Batsman['Times Out'] = Batsman['Times Out'].astype(float)

# %%
BR= Batsman.groupby(by=['Players','Team'])[['Match Played','Batsman Runs','Balls','Fours','Sixes','50s','100s','Times Out']].sum().nlargest(100,columns=['Batsman Runs'])

# %%
BR['Strike Rate'] = BR['Batsman Runs']/BR['Balls']*100

# %%
batsman= BR.round(2)

# %%
batsman.loc[batsman['Times Out'] ==0,'Average']  = batsman['Batsman Runs']/batsman['Match Played']
batsman.loc[(batsman['Times Out'] == 1) & (batsman['Match Played'] == 1),'Average'] = batsman['Batsman Runs']
batsman.loc[(batsman['Times Out'] == 1) & (batsman['Match Played'] >= 2),'Average'] = batsman['Batsman Runs']/(batsman['Match Played']-batsman['Times Out'])
batsman.loc[(batsman['Times Out'] == 2) & (batsman['Match Played'] == 2),'Average'] = batsman['Batsman Runs']
batsman.loc[(batsman['Times Out'] == 3) & (batsman['Match Played'] == 3),'Average'] = batsman['Batsman Runs']
batsman.loc[(batsman['Times Out'] == 2) & (batsman['Match Played'] >= 3),'Average'] = batsman['Batsman Runs']/(batsman['Match Played']-1)

# %%
batsman.loc[batsman['Balls'] >=1 , 'Innings'] = batsman['Match Played']

# %%
batsman.head(1)
# Out:
#                                Match Played  Batsman Runs  Balls  Fours  \
# Players        Team
# Shikhar Dhawan Delhi Capitals             3           186    114     24
#
#                                Sixes  50s  100s  Times Out  Strike Rate  \
# Players        Team
# Shikhar Dhawan Delhi Capitals      4    2     0        0.0       163.16
#
#                                Average  Innings
# Players        Team
# Shikhar Dhawan Delhi Capitals     62.0        3

# %% [markdown]
# ## Most Runs

# %%
batsman[['Match Played','Innings','Batsman Runs','Average']].nlargest(1500,'Batsman Runs').round(2)
# Out:
#                                               Match Played  Innings  \
# Players           Team
# Shikhar Dhawan    Delhi Capitals                         3        3
# Glenn Maxwell     Royal Challengers Banglore             3        3
# KL Rahul          Punjab Kings                           3        3
# Nitish Rana       Kolkata Knight Riders                  3        3
# AB de Villiers    Royal Challengers Banglore             3        3
# ...                                                    ...      ...
# Mustafizur Rahman Rajasthan Royals                       1        1
# Shahbaz Nadeem    Sunrisers Hyderabad                    1        1
# Mohammed Siraj    Royal Challengers Banglore             1        1
# Marco Jansen      Mumbai Indians                         2        2
# Ben Stokes        Rajasthan Royals                       1        1
#
#                                               Batsman Runs  Average
# Players           Team
# Shikhar Dhawan    Delhi Capitals                       186    62.00
# Glenn Maxwell     Royal Challengers Banglore           176    58.67
# KL Rahul          Punjab Kings                         157    52.33
# Nitish Rana       Kolkata Knight Riders                155    51.67
# AB de Villiers    Royal Challengers Banglore           125    62.50
# ...                                                    ...      ...
# Mustafizur Rahman Rajasthan Royals                       0     0.00
# Shahbaz Nadeem    Sunrisers Hyderabad                    0     0.00
# Mohammed Siraj    Royal Challengers Banglore             0     0.00
# Marco Jansen      Mumbai Indians                         0     0.00
# Ben Stokes        Rajasthan Royals                       0     0.00
#
# [88 rows x 4 columns]

# %% [markdown]
# ## Highest Scores

# %%
Batsman[['Batsman Runs','Balls','Strike Rate','Vs']].nlargest(15,'Batsman Runs')
# Out:
#                 Batsman Runs  Balls  Strike Rate    Vs
# Players
# Sanju Samson             119     63       188.89  PBKS
# Shikhar Dhawan            92     49       187.76  PBKS
# KL Rahul                  91     50       182.00    RR
# Shikhar Dhawan            85     54       157.41   CSK
# Nitish Rana               80     56       142.86   SRH
# Glenn Maxwell             78     49       159.18   KKR
# AB de Villiers            76     34       223.53   KKR
# Prithvi Shaw              72     38       189.47   CSK
# Mayank Agarwal            69     36       191.67    DC
# Deepak Hooda              64     28       228.57    RR
# David Miller              62     43       144.19    DC
# KL Rahul                  61     51       119.61    DC
# Manish Pandey             61     44       138.64   KKR
# Glenn Maxwell             59     41       143.90   SRH
# Nitish Rana               57     47       121.28    MI

# %% [markdown]
# ## Best Batting Strike Rate

# %%
SR= batsman[batsman['Batsman Runs'] >=50].nlargest(15,'Strike Rate')

# %%
SR[['Match Played','Innings','Batsman Runs','Strike Rate']].nlargest(15,'Strike Rate')
# Out:
#                                              Match Played  Innings  \
# Players          Team
# Sam Curran       Chennai Super Kings                    3        3
# AB de Villiers   Royal Challengers Banglore             3        3
# Prithvi Shaw     Delhi Capitals                         3        3
# Mayank Agarwal   Punjab Kings                           3        3
# Sanju Samson     Rajasthan Royals                       3        3
# Deepak Hooda     Punjab Kings                           3        3
# Shikhar Dhawan   Delhi Capitals                         3        3
# Rahul Tripathi   Kolkata Knight Riders                  3        3
# Shahrukh Khan    Punjab Kings                           3        3
# Shubman Gill     Kolkata Knight Riders                  3        3
# Suryakumar Yadav Mumbai Indians                         3        3
# Glenn Maxwell    Royal Challengers Banglore             3        3
# Ambati Rayudu    Chennai Super Kings                    3        3
# Jonny Bairstow   Sunrisers Hyderabad                    3        3
# KL Rahul         Punjab Kings                           3        3
#
#                                              Batsman Runs  Strike Rate
# Players          Team
# Sam Curran       Chennai Super Kings                   52       208.00
# AB de Villiers   Royal Challengers Banglore           125       189.39
# Prithvi Shaw     Delhi Capitals                       106       176.67
# Mayank Agarwal   Punjab Kings                          83       176.60
# Sanju Samson     Rajasthan Royals                     124       174.65
# Deepak Hooda     Punjab Kings                          96       171.43
# Shikhar Dhawan   Delhi Capitals                       186       163.16
# Rahul Tripathi   Kolkata Knight Riders                 83       153.70
# Shahrukh Khan    Punjab Kings                          68       151.11
# Shubman Gill     Kolkata Knight Riders                 69       150.00
# Suryakumar Yadav Mumbai Indians                        97       149.23
# Glenn Maxwell    Royal Challengers Banglore           176       149.15
# Ambati Rayudu    Chennai Super Kings                   50       147.06
# Jonny Bairstow   Sunrisers Hyderabad                  110       146.67
# KL Rahul         Punjab Kings                         157       145.37

# %% [markdown]
# ## Best Batting Average

# %%
batsman[['Match Played','Innings','Batsman Runs','Average']].nlargest(1500,'Average').round(2)
# Out:
#                                               Match Played  Innings  \
# Players           Team
# AB de Villiers    Royal Challengers Banglore             3        3
# Shikhar Dhawan    Delhi Capitals                         3        3
# Glenn Maxwell     Royal Challengers Banglore             3        3
# KL Rahul          Punjab Kings                           3        3
# Nitish Rana       Kolkata Knight Riders                  3        3
# ...                                                    ...      ...
# Mustafizur Rahman Rajasthan Royals                       1        1
# Shahbaz Nadeem    Sunrisers Hyderabad                    1        1
# Mohammed Siraj    Royal Challengers Banglore             1        1
# Marco Jansen      Mumbai Indians                         2        2
# Ben Stokes        Rajasthan Royals                       1        1
#
#                                               Batsman Runs  Average
# Players           Team
# AB de Villiers    Royal Challengers Banglore           125    62.50
# Shikhar Dhawan    Delhi Capitals                       186    62.00
# Glenn Maxwell     Royal Challengers Banglore           176    58.67
# KL Rahul          Punjab Kings                         157    52.33
# Nitish Rana       Kolkata Knight Riders                155    51.67
# ...                                                    ...      ...
# Mustafizur Rahman Rajasthan Royals                       0     0.00
# Shahbaz Nadeem    Sunrisers Hyderabad                    0     0.00
# Mohammed Siraj    Royal Challengers Banglore             0     0.00
# Marco Jansen      Mumbai Indians                         0     0.00
# Ben Stokes        Rajasthan Royals                       0     0.00
#
# [88 rows x 4 columns]

# %%
batsman[['Match Played','Innings','Batsman Runs','50s']].nlargest(10,'50s')
# Out:
#                                              Match Played  Innings  \
# Players          Team
# Shikhar Dhawan   Delhi Capitals                         3        3
# Glenn Maxwell    Royal Challengers Banglore             3        3
# KL Rahul         Punjab Kings                           3        3
# Nitish Rana      Kolkata Knight Riders                  3        3
# AB de Villiers   Royal Challengers Banglore             3        3
# Jonny Bairstow   Sunrisers Hyderabad                    3        3
# Prithvi Shaw     Delhi Capitals                         3        3
# Manish Pandey    Sunrisers Hyderabad                    3        3
# Suryakumar Yadav Mumbai Indians                         3        3
# Deepak Hooda     Punjab Kings                           3        3
#
#                                              Batsman Runs  50s
# Players          Team
# Shikhar Dhawan   Delhi Capitals                       186    2
# Glenn Maxwell    Royal Challengers Banglore           176    2
# KL Rahul         Punjab Kings                         157    2
# Nitish Rana      Kolkata Knight Riders                155    2
# AB de Villiers   Royal Challengers Banglore           125    1
# Jonny Bairstow   Sunrisers Hyderabad                  110    1
# Prithvi Shaw     Delhi Capitals                       106    1
# Manish Pandey    Sunrisers Hyderabad                  101    1
# Suryakumar Yadav Mumbai Indians                        97    1
# Deepak Hooda     Punjab Kings                          96    1

# %%
batsman[['Match Played','Innings','Batsman Runs','Fours']].nlargest(10,'Fours')
# Out:
#                                              Match Played  Innings  \
# Players          Team
# Shikhar Dhawan   Delhi Capitals                         3        3
# Glenn Maxwell    Royal Challengers Banglore             3        3
# Nitish Rana      Kolkata Knight Riders                  3        3
# KL Rahul         Punjab Kings                           3        3
# AB de Villiers   Royal Challengers Banglore             3        3
# Sanju Samson     Rajasthan Royals                       3        3
# Moeen Ali        Chennai Super Kings                    3        3
# Prithvi Shaw     Delhi Capitals                         3        3
# Suryakumar Yadav Mumbai Indians                         3        3
# Rishabh Pant     Delhi Capitals                         3        3
#
#                                              Batsman Runs  Fours
# Players          Team
# Shikhar Dhawan   Delhi Capitals                       186     24
# Glenn Maxwell    Royal Challengers Banglore           176     17
# Nitish Rana      Kolkata Knight Riders                155     17
# KL Rahul         Punjab Kings                         157     15
# AB de Villiers   Royal Challengers Banglore           125     13
# Sanju Samson     Rajasthan Royals                     124     13
# Moeen Ali        Chennai Super Kings                  108     12
# Prithvi Shaw     Delhi Capitals                       106     12
# Suryakumar Yadav Mumbai Indians                        97     12
# Rishabh Pant     Delhi Capitals                        81     11

# %%
batsman[['Match Played','Innings','Batsman Runs','Sixes']].nlargest(10,'Sixes')
# Out:
#                                            Match Played  Innings  \
# Players        Team
# Glenn Maxwell  Royal Challengers Banglore             3        3
# Deepak Hooda   Punjab Kings                           3        3
# KL Rahul       Punjab Kings                           3        3
# Nitish Rana    Kolkata Knight Riders                  3        3
# Sanju Samson   Rajasthan Royals                       3        3
# Jonny Bairstow Sunrisers Hyderabad                    3        3
# AB de Villiers Royal Challengers Banglore             3        3
# Moeen Ali      Chennai Super Kings                    3        3
# Prithvi Shaw   Delhi Capitals                         3        3
# Manish Pandey  Sunrisers Hyderabad                    3        3
#
#                                            Batsman Runs  Sixes
# Players        Team
# Glenn Maxwell  Royal Challengers Banglore           176      8
# Deepak Hooda   Punjab Kings                          96      8
# KL Rahul       Punjab Kings                         157      7
# Nitish Rana    Kolkata Knight Riders                155      7
# Sanju Samson   Rajasthan Royals                     124      7
# Jonny Bairstow Sunrisers Hyderabad                  110      7
# AB de Villiers Royal Challengers Banglore           125      5
# Moeen Ali      Chennai Super Kings                  108      5
# Prithvi Shaw   Delhi Capitals                       106      5
# Manish Pandey  Sunrisers Hyderabad                  101      5

# %% [markdown]
# # BOWLERS

# %%
bowler_played= df[['Team','Match Played','Over','Bowler Balls','Maiden','Bowler Runs','Wickets','Economy Rate','Vs']]

# %%
Bowler= bowler_played[bowler_played['Bowler Balls'] >=1]

# %%
W= Bowler.groupby(by=['Players','Team'])[['Match Played','Over','Bowler Balls','Maiden','Bowler Runs','Wickets']].sum().nlargest(100,'Wickets')

# %%
W['Economy'] = W['Bowler Runs']/W['Over']

# %%
W['Average'] = W['Bowler Runs']/W['Wickets']

# %%
W['Strike Rate'] = W['Bowler Balls']/W['Wickets']

# %%
bowler = W.round(2)

# %%
bowler.sort_values(by='Wickets',ascending=False).shape
# Out:
# (64, 9)

# %% [markdown]
# ## Most Wickets

# %%
bowler[['Match Played','Over','Wickets','Average']].nlargest(10,'Wickets')
# Out:
#                                             Match Played  Over  Wickets  \
# Players         Team
# Harshal Patel   Royal Challengers Banglore             3  12.0        9
# Rahul Chahar    Mumbai Indians                         3  12.0        7
# Andre Russell   Kolkata Knight Riders                  3   7.0        6
# Avesh Khan      Delhi Capitals                         3  12.0        6
# Chetan Sakariya Rajasthan Royals                       3  12.0        6
# Trent Boult     Mumbai Indians                         3  11.4        6
# Kyle Jamieson   Royal Challengers Banglore             3  10.0        5
# Arshdeep Singh  Punjab Kings                           3   9.0        5
# Chris Morris    Rajasthan Royals                       3  11.0        5
# Chris Woakes    Delhi Capitals                         3  11.0        5
#
#                                             Average
# Players         Team
# Harshal Patel   Royal Challengers Banglore     7.67
# Rahul Chahar    Mumbai Indians                12.71
# Andre Russell   Kolkata Knight Riders         14.17
# Avesh Khan      Delhi Capitals                14.67
# Chetan Sakariya Rajasthan Royals              16.67
# Trent Boult     Mumbai Indians                15.17
# Kyle Jamieson   Royal Challengers Banglore    19.60
# Arshdeep Singh  Punjab Kings                  12.80
# Chris Morris    Rajasthan Royals              20.20
# Chris Woakes    Delhi Capitals                16.40

# %% [markdown]
# ## Best Bowling Average

# %%
BA= bowler[bowler['Wickets'] >5].nsmallest(10,'Average')

# %%
BA[['Match Played','Over','Bowler Runs','Wickets','Average']].nsmallest(40,'Average')
# Out:
#                                             Match Played  Over  Bowler Runs  \
# Players         Team
# Harshal Patel   Royal Challengers Banglore             3  12.0           69
# Rahul Chahar    Mumbai Indians                         3  12.0           89
# Andre Russell   Kolkata Knight Riders                  3   7.0           85
# Avesh Khan      Delhi Capitals                         3  12.0           88
# Trent Boult     Mumbai Indians                         3  11.4           91
# Chetan Sakariya Rajasthan Royals                       3  12.0          100
#
#                                             Wickets  Average
# Players         Team
# Harshal Patel   Royal Challengers Banglore        9     7.67
# Rahul Chahar    Mumbai Indians                    7    12.71
# Andre Russell   Kolkata Knight Riders             6    14.17
# Avesh Khan      Delhi Capitals                    6    14.67
# Trent Boult     Mumbai Indians                    6    15.17
# Chetan Sakariya Rajasthan Royals                  6    16.67

# %% [markdown]
# ## Best Bowling Strike Rate

# %%
SR= bowler[bowler['Wickets'] >=5].nsmallest(10,'Strike Rate')

# %%
SR[['Match Played','Over','Wickets','Strike Rate']].nsmallest(10,'Strike Rate')
# Out:
#                                             Match Played  Over  Wickets  \
# Players         Team
# Andre Russell   Kolkata Knight Riders                  3   7.0        6
# Harshal Patel   Royal Challengers Banglore             3  12.0        9
# Rahul Chahar    Mumbai Indians                         3  12.0        7
# Arshdeep Singh  Punjab Kings                           3   9.0        5
# Trent Boult     Mumbai Indians                         3  11.4        6
# Avesh Khan      Delhi Capitals                         3  12.0        6
# Chetan Sakariya Rajasthan Royals                       3  12.0        6
# Kyle Jamieson   Royal Challengers Banglore             3  10.0        5
# Chris Morris    Rajasthan Royals                       3  11.0        5
# Chris Woakes    Delhi Capitals                         3  11.0        5
#
#                                             Strike Rate
# Players         Team
# Andre Russell   Kolkata Knight Riders              7.00
# Harshal Patel   Royal Challengers Banglore         8.00
# Rahul Chahar    Mumbai Indians                    10.29
# Arshdeep Singh  Punjab Kings                      10.80
# Trent Boult     Mumbai Indians                    11.67
# Avesh Khan      Delhi Capitals                    12.00
# Chetan Sakariya Rajasthan Royals                  12.00
# Kyle Jamieson   Royal Challengers Banglore        12.00
# Chris Morris    Rajasthan Royals                  13.20
# Chris Woakes    Delhi Capitals                    13.20

# %% [markdown]
# ## Best Economy

# %%
bowler[['Match Played','Over','Wickets','Economy']].nsmallest(10,'Economy')
# Out:
#                                             Match Played  Over  Wickets  \
# Players         Team
# Abhishek Sharma Sunrisers Hyderabad                    1   1.0        0
# Rashid Khan     Sunrisers Hyderabad                    3  12.0        4
# Jasprit Bumrah  Mumbai Indians                         3  12.0        3
# Harshal Patel   Royal Challengers Banglore             3  12.0        9
# Mohammed Siraj  Royal Challengers Banglore             3  11.0        2
# Khaleel Ahmed   Sunrisers Hyderabad                    1   4.0        1
# Krunal Pandya   Mumbai Indians                         3  11.0        3
# Ravindra Jadeja Chennai Super Kings                    3  10.0        2
# Moeen Ali       Chennai Super Kings                    3   9.0        4
# Sam Curran      Chennai Super Kings                    3   9.0        3
#
#                                             Economy
# Players         Team
# Abhishek Sharma Sunrisers Hyderabad            5.00
# Rashid Khan     Sunrisers Hyderabad            5.33
# Jasprit Bumrah  Mumbai Indians                 5.67
# Harshal Patel   Royal Challengers Banglore     5.75
# Mohammed Siraj  Royal Challengers Banglore     5.82
# Khaleel Ahmed   Sunrisers Hyderabad            6.00
# Krunal Pandya   Mumbai Indians                 6.18
# Ravindra Jadeja Chennai Super Kings            6.30
# Moeen Ali       Chennai Super Kings            6.33
# Sam Curran      Chennai Super Kings            6.67
